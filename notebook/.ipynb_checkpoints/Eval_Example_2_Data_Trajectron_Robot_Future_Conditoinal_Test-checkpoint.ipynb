# %%
using Revise

ENV["PYCALL_JL_RUNTIME_PYTHON"] = Sys.which("python")
using FileIO
using JLD2
using RiskSensitiveSAC
# Out:
# ┌ Info: Precompiling RiskSensitiveSAC [e1fab9f6-18d5-46a3-a575-fcee50e8520a]
# └ @ Base loading.jl:1278
# ┌ Info: Number of Julia Thread(s): 1
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:39
# ┌ Info: CUDA Device: GeForce RTX 2080 Ti
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:40
# ┌ Info: Python executable used by PyCall: /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/env_trajectron++/bin/python3.6
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:41

# %% [markdown]
# # 1. Default

# %%
include("$(@__DIR__)/../scripts/default_params/params_data_trajectron.jl");

incl_robot_node = true;
use_robot_future = true;
sim_horizon = 4.4;
prediction_rng_seed = 123;

include("$(@__DIR__)/../scripts/parameter_setup.jl");

# %%
scene_loader, controller, w_init, measurement_schedule, target_trajectory, target_speed =
controller_setup(scene_param,
                 predictor_param,
                 prediction_device=prediction_device,
                 cost_param=cost_param,
                 cnt_param=cnt_param,
                 dtc=dtc,
                 sim_horizon=sim_horizon,
                 ado_id_to_replace="PEDESTRIAN/236",
                 verbose=true);
# Out:
# Scene Mode: data
# Prediction Mode: trajectron
# Deterministic Prediction: false
# Loaded evaluation data from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/processed/eth_test.pkl
# Looking at the eth_test.pkl sequence, data_id 0, start_idx 905
# Found PEDESTRIAN/236. start_time_idx updated to: 909 Re-loading Scene...
# Loaded evaluation data from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/processed/eth_test.pkl
# Looking at the eth_test.pkl sequence, data_id 0, start_idx 909
# Loaded Trajectron model from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/pedestrians/models/models_21_Apr_2020_20_15_41_eth_ar3_rob/model_registrar-100.pt
# Note initial time is set to 1.6 [s].

# %%
result, controller, ado_inputs = 
evaluate(scene_loader, controller, w_init, maximum(target_trajectory)[2],
         target_speed, measurement_schedule, target_trajectory,
         pos_error_replan, nominal_control=false,
         ado_id_removed="PEDESTRIAN/236");
# Out:
# ┌ Warning: Time 2.16 [sec]: This evaluation iteration took 0.056 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:254

# %%
display_log(result.log)
# Out:
# Time 1.60 [sec]: New prediction is available to the controller.
# Time 1.60 [sec]: New SAC control computation is scheduled.
# Time 1.60 [sec]: New SAC control is available to the controller.
# Time 1.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.70 [sec]: New SAC control computation is scheduled.
# Time 1.70 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.72 [sec]: New SAC control is available to the controller.
# Time 1.72 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.74 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.76 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.78 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.80 [sec]: New SAC control computation is scheduled.
# Time 1.80 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 1.82 [sec]: New SAC control is available to the controller.
# Time 1.82 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 1.84 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 1.86 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 1.88 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 1.90 [sec]: New SAC control computation is scheduled.
# Time 1.90 [sec]: Control: [3.119908972958135, -3.9071943898986277] is applied to the system.
# Time 1.92 [sec]: New SAC control is available to the controller.
# Time 1.92 [sec]: Control: [3.1199090480804443, -3.9071943759918213] is applied to the system.
# Time 1.94 [sec]: Control: [3.1199090480804443, -3.9071943759918213] is applied to the system.
# Time 1.96 [sec]: Control: [3.1199090480804443, -3.9071943759918213] is applied to the system.
# Time 1.98 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.00 [sec]: New measurement is obtained.
# Time 2.00 [sec]: New prediction is scheduled.
# Time 2.00 [sec]: New SAC control computation is scheduled.
# Time 2.00 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.02 [sec]: New prediction is available to the controller.
# Time 2.02 [sec]: New SAC control is available to the controller.
# Time 2.02 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.04 [sec]: Control: [4.999046802520752, 0.09761851280927658] is applied to the system.
# Time 2.06 [sec]: Control: [4.999046802520752, 0.09761851280927658] is applied to the system.
# Time 2.08 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.10 [sec]: New SAC control computation is scheduled.
# Time 2.10 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.12 [sec]: New SAC control is available to the controller.
# Time 2.12 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.14 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.16 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.18 [sec]: Control: [0.0, 2.0] is applied to the system.
# Time 2.20 [sec]: New SAC control computation is scheduled.
# Time 2.20 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.22 [sec]: New SAC control is available to the controller.
# Time 2.22 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.24 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.26 [sec]: Control: [-1.3816556930541992, -1.4460384845733643] is applied to the system.
# Time 2.28 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.30 [sec]: New SAC control computation is scheduled.
# Time 2.30 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.32 [sec]: New SAC control is available to the controller.
# Time 2.32 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.34 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.36 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.38 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.40 [sec]: New measurement is obtained.
# Time 2.40 [sec]: New prediction is scheduled.
# Time 2.40 [sec]: New SAC control computation is scheduled.
# Time 2.40 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.42 [sec]: New prediction is available to the controller.
# Time 2.42 [sec]: New SAC control is available to the controller.
# Time 2.42 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.44 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.46 [sec]: Control: [-0.3810085356235504, -0.021715378388762474] is applied to the system.
# Time 2.48 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.50 [sec]: New SAC control computation is scheduled.
# Time 2.50 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.52 [sec]: New SAC control is available to the controller.
# Time 2.52 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.54 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.56 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.58 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.60 [sec]: New SAC control computation is scheduled.
# Time 2.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.62 [sec]: New SAC control is available to the controller.
# Time 2.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.70 [sec]: New SAC control computation is scheduled.
# Time 2.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.72 [sec]: New SAC control is available to the controller.
# Time 2.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.80 [sec]: New measurement is obtained.
# Time 2.80 [sec]: New prediction is scheduled.
# Time 2.80 [sec]: New SAC control computation is scheduled.
# Time 2.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.82 [sec]: New prediction is available to the controller.
# Time 2.82 [sec]: New SAC control is available to the controller.
# Time 2.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.86 [sec]: Control: [-1.5458611249923706, 0.5694307088851929] is applied to the system.
# Time 2.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.90 [sec]: New SAC control computation is scheduled.
# Time 2.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.92 [sec]: New SAC control is available to the controller.
# Time 2.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.00 [sec]: New SAC control computation is scheduled.
# Time 3.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.02 [sec]: New SAC control is available to the controller.
# Time 3.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.10 [sec]: New SAC control computation is scheduled.
# Time 3.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.12 [sec]: New SAC control is available to the controller.
# Time 3.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.20 [sec]: New measurement is obtained.
# Time 3.20 [sec]: New prediction is scheduled.
# Time 3.20 [sec]: New SAC control computation is scheduled.
# Time 3.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.22 [sec]: New prediction is available to the controller.
# Time 3.22 [sec]: New SAC control is available to the controller.
# Time 3.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.30 [sec]: New SAC control computation is scheduled.
# Time 3.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.32 [sec]: New SAC control is available to the controller.
# Time 3.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.40 [sec]: New SAC control computation is scheduled.
# Time 3.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.42 [sec]: New SAC control is available to the controller.
# Time 3.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.50 [sec]: New SAC control computation is scheduled.
# Time 3.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.52 [sec]: New SAC control is available to the controller.
# Time 3.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.60 [sec]: New measurement is obtained.
# Time 3.60 [sec]: New prediction is scheduled.
# Time 3.60 [sec]: New SAC control computation is scheduled.
# Time 3.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.62 [sec]: New prediction is available to the controller.
# Time 3.62 [sec]: New SAC control is available to the controller.
# Time 3.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.70 [sec]: New SAC control computation is scheduled.
# Time 3.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.72 [sec]: New SAC control is available to the controller.
# Time 3.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.80 [sec]: New SAC control computation is scheduled.
# Time 3.80 [sec]: Control: [4.0, 0.0] is applied to the system.
# Time 3.82 [sec]: New SAC control is available to the controller.
# Time 3.82 [sec]: Control: [4.0, 0.0] is applied to the system.
# Time 3.84 [sec]: Control: [4.0, 0.0] is applied to the system.
# Time 3.86 [sec]: Control: [-0.2494167536497116, 0.01706703007221222] is applied to the system.
# Time 3.88 [sec]: Control: [4.0, 0.0] is applied to the system.
# Time 3.90 [sec]: New SAC control computation is scheduled.
# Time 3.90 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 3.92 [sec]: New SAC control is available to the controller.
# Time 3.92 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 3.94 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 3.96 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 3.98 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 4.00 [sec]: New measurement is obtained.
# Time 4.00 [sec]: New prediction is scheduled.
# Time 4.00 [sec]: New SAC control computation is scheduled.
# Time 4.00 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 4.02 [sec]: New prediction is available to the controller.
# Time 4.02 [sec]: New SAC control is available to the controller.
# Time 4.02 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 4.04 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 4.06 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 4.08 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 4.10 [sec]: New SAC control computation is scheduled.
# Time 4.10 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.12 [sec]: New SAC control is available to the controller.
# Time 4.12 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.14 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.16 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.18 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.20 [sec]: New SAC control computation is scheduled.
# Time 4.20 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.22 [sec]: New SAC control is available to the controller.
# Time 4.22 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.24 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.26 [sec]: Control: [-0.1133456826210022, 3.9983937740325928] is applied to the system.
# Time 4.28 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.30 [sec]: New SAC control computation is scheduled.
# Time 4.30 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.32 [sec]: New SAC control is available to the controller.
# Time 4.32 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.34 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.36 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.38 [sec]: Position deviation: 2.0157. Target Trajectory is replanned.
# Time 4.38 [sec]: Control: [-0.0, -4.0] is applied to the system.
# Time 4.40 [sec]: New measurement is obtained.

# %%
e_state = result.w_history[end].e_state;
w = result.w_history[end];
u_schedule = result.u_schedule_history[end];
target_trajectory = result.target_trajectory_history[end];

# %%
rpf = get_robot_present_and_future(e_state, u_schedule, controller.sim_param, controller.cnt_param);

# %%
function get_clipped_prediction_dict(prediction_dict::Dict{String, Array{Float64, 3}},
                                     num_samples::Int64,
                                     nominal_control_idx::Int64)
    clipped_preds_dict = Dict{String, Array{Float64, 3}}();
    for key in keys(prediction_dict)
        clipped_array =
            prediction_dict[key][num_samples*(nominal_control_idx - 1) + 1:num_samples*nominal_control_idx, :, :];
        clipped_preds_dict[key] = copy(clipped_array);
    end
    return clipped_preds_dict
end
# Out:
# get_clipped_prediction_dict (generic function with 1 method)

# %%
prediction_dict = sample_future_ado_positions!(controller.predictor, ado_inputs, rpf);

# %%
u_nominal_idx = 12;
prediction_dict_clipped = get_clipped_prediction_dict(prediction_dict,
                                              num_samples, u_nominal_idx)
nominal_trajectory = [rpf[u_nominal_idx, t, 1:2] for t = 1:size(rpf, 2)];
plt = visualize!(Dict(), w, target_trajectory, prediction_dict_clipped, num_samples, nominal_trajectory,
         xlim=(-3. + -5.263534, 13. + -5.314636), 
         ylim=(0. + -5.263534, 10. + -5.314636), figsize=(600, 400), 
         legendfontsize=7, legend=:bottomright, markersize=5)

# %%
u_nominal_idx = 6;
prediction_dict_clipped = get_clipped_prediction_dict(prediction_dict,
                                              num_samples, u_nominal_idx)
nominal_trajectory = [rpf[u_nominal_idx, t, 1:2] for t = 1:size(rpf, 2)];
plt = visualize!(Dict(), w, target_trajectory, prediction_dict_clipped, num_samples, nominal_trajectory,
         xlim=(-3. + -5.263534, 13. + -5.314636), 
         ylim=(0. + -5.263534, 10. + -5.314636), figsize=(600, 400), 
         legendfontsize=7, legend=:bottomright, markersize=5)

# %% [markdown]
# # 2. Deterministic (mode-mode) Prediction

# %%
include("$(@__DIR__)/../scripts/default_params/params_data_trajectron.jl");

incl_robot_node = true;
use_robot_future = true;
sim_horizon = 4.4;
num_samples = 1;
deterministic = true;

include("$(@__DIR__)/../scripts/parameter_setup.jl");

# %%
scene_loader, controller, w_init, measurement_schedule, target_trajectory, target_speed =
controller_setup(scene_param,
                 predictor_param,
                 prediction_device=prediction_device,
                 cost_param=cost_param,
                 cnt_param=cnt_param,
                 dtc=dtc,
                 sim_horizon=sim_horizon,
                 ado_id_to_replace="PEDESTRIAN/236",
                 verbose=true);
# Out:
# Scene Mode: data
# Prediction Mode: trajectron
# Deterministic Prediction: true
# Loaded evaluation data from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/processed/eth_test.pkl
# Looking at the eth_test.pkl sequence, data_id 0, start_idx 905
# Found PEDESTRIAN/236. start_time_idx updated to: 909 Re-loading Scene...
# Loaded evaluation data from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/processed/eth_test.pkl
# Looking at the eth_test.pkl sequence, data_id 0, start_idx 909
# Loaded Trajectron model from /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/Trajectron-plus-plus/experiments/pedestrians/models/models_21_Apr_2020_20_15_41_eth_ar3_rob/model_registrar-100.pt
# Note initial time is set to 1.6 [s].

# %%
result, controller, ado_inputs = 
evaluate(scene_loader, controller, w_init, maximum(target_trajectory)[2],
         target_speed, measurement_schedule, target_trajectory,
         pos_error_replan, nominal_control=false,
         ado_id_removed="PEDESTRIAN/236");

# %%
display_log(result.log)
# Out:
# Time 1.60 [sec]: New prediction is available to the controller.
# Time 1.60 [sec]: New SAC control computation is scheduled.
# Time 1.60 [sec]: New SAC control is available to the controller.
# Time 1.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 1.70 [sec]: New SAC control computation is scheduled.
# Time 1.70 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.72 [sec]: New SAC control is available to the controller.
# Time 1.72 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.74 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.76 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.78 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.80 [sec]: New SAC control computation is scheduled.
# Time 1.80 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.82 [sec]: New SAC control is available to the controller.
# Time 1.82 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.84 [sec]: Control: [-2.483043909072876, -4.339872360229492] is applied to the system.
# Time 1.86 [sec]: Control: [-2.483043909072876, -4.339872360229492] is applied to the system.
# Time 1.88 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.90 [sec]: New SAC control computation is scheduled.
# Time 1.90 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.92 [sec]: New SAC control is available to the controller.
# Time 1.92 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.94 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.96 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 1.98 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 2.00 [sec]: New measurement is obtained.
# Time 2.00 [sec]: New prediction is scheduled.
# Time 2.00 [sec]: New SAC control computation is scheduled.
# Time 2.00 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.02 [sec]: New prediction is available to the controller.
# Time 2.02 [sec]: New SAC control is available to the controller.
# Time 2.02 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.04 [sec]: Control: [3.9108176231384277, -3.115365982055664] is applied to the system.
# Time 2.06 [sec]: Control: [3.9108176231384277, -3.115365982055664] is applied to the system.
# Time 2.08 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.10 [sec]: New SAC control computation is scheduled.
# Time 2.10 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.12 [sec]: New SAC control is available to the controller.
# Time 2.12 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.14 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.16 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.18 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.20 [sec]: New SAC control computation is scheduled.
# Time 2.20 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.22 [sec]: New SAC control is available to the controller.
# Time 2.22 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.24 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.26 [sec]: Control: [-0.7711572647094727, 0.27204039692878723] is applied to the system.
# Time 2.28 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.30 [sec]: New SAC control computation is scheduled.
# Time 2.30 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.32 [sec]: New SAC control is available to the controller.
# Time 2.32 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.34 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.36 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.38 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.40 [sec]: New measurement is obtained.
# Time 2.40 [sec]: New prediction is scheduled.
# Time 2.40 [sec]: New SAC control computation is scheduled.
# Time 2.40 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.42 [sec]: New prediction is available to the controller.
# Time 2.42 [sec]: New SAC control is available to the controller.
# Time 2.42 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.44 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.46 [sec]: Control: [-0.5884034633636475, 0.32700055837631226] is applied to the system.
# Time 2.48 [sec]: Control: [1.4142099618911743, 1.4142099618911743] is applied to the system.
# Time 2.50 [sec]: New SAC control computation is scheduled.
# Time 2.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.52 [sec]: New SAC control is available to the controller.
# Time 2.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.60 [sec]: New SAC control computation is scheduled.
# Time 2.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.62 [sec]: New SAC control is available to the controller.
# Time 2.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.66 [sec]: Control: [-1.3886061906814575, 0.9434725046157837] is applied to the system.
# Time 2.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.70 [sec]: New SAC control computation is scheduled.
# Time 2.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.72 [sec]: New SAC control is available to the controller.
# Time 2.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.80 [sec]: New measurement is obtained.
# Time 2.80 [sec]: New prediction is scheduled.
# Time 2.80 [sec]: New SAC control computation is scheduled.
# Time 2.80 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.82 [sec]: New prediction is available to the controller.
# Time 2.82 [sec]: New SAC control is available to the controller.
# Time 2.82 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.84 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.86 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.88 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.90 [sec]: New SAC control computation is scheduled.
# Time 2.90 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.92 [sec]: New SAC control is available to the controller.
# Time 2.92 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.94 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.96 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 2.98 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.00 [sec]: New SAC control computation is scheduled.
# Time 3.00 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.02 [sec]: New SAC control is available to the controller.
# Time 3.02 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.04 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.06 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.08 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.10 [sec]: New SAC control computation is scheduled.
# Time 3.10 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.12 [sec]: New SAC control is available to the controller.
# Time 3.12 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.14 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.16 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.18 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.20 [sec]: New measurement is obtained.
# Time 3.20 [sec]: New prediction is scheduled.
# Time 3.20 [sec]: New SAC control computation is scheduled.
# Time 3.20 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.22 [sec]: New prediction is available to the controller.
# Time 3.22 [sec]: New SAC control is available to the controller.
# Time 3.22 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.24 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.26 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.28 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.30 [sec]: New SAC control computation is scheduled.
# Time 3.30 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.32 [sec]: New SAC control is available to the controller.
# Time 3.32 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.34 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.36 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.38 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.40 [sec]: New SAC control computation is scheduled.
# Time 3.40 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.42 [sec]: New SAC control is available to the controller.
# Time 3.42 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.44 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.46 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.48 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.50 [sec]: New SAC control computation is scheduled.
# Time 3.50 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.52 [sec]: New SAC control is available to the controller.
# Time 3.52 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.54 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.56 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.58 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.60 [sec]: New measurement is obtained.
# Time 3.60 [sec]: New prediction is scheduled.
# Time 3.60 [sec]: New SAC control computation is scheduled.
# Time 3.60 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.62 [sec]: New prediction is available to the controller.
# Time 3.62 [sec]: New SAC control is available to the controller.
# Time 3.62 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.64 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.66 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.68 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.70 [sec]: New SAC control computation is scheduled.
# Time 3.70 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.72 [sec]: New SAC control is available to the controller.
# Time 3.72 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.74 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.76 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.78 [sec]: Control: [0.0, 0.0] is applied to the system.
# Time 3.80 [sec]: New SAC control computation is scheduled.
# Time 3.80 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 3.82 [sec]: New SAC control is available to the controller.
# Time 3.82 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 3.84 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 3.86 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 3.88 [sec]: Control: [-0.0, -2.0] is applied to the system.
# Time 3.90 [sec]: New SAC control computation is scheduled.
# Time 3.90 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.92 [sec]: New SAC control is available to the controller.
# Time 3.92 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.94 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.96 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 3.98 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.00 [sec]: New measurement is obtained.
# Time 4.00 [sec]: New prediction is scheduled.
# Time 4.00 [sec]: New SAC control computation is scheduled.
# Time 4.00 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.02 [sec]: New prediction is available to the controller.
# Time 4.02 [sec]: New SAC control is available to the controller.
# Time 4.02 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.04 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.06 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.08 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.10 [sec]: New SAC control computation is scheduled.
# Time 4.10 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.12 [sec]: New SAC control is available to the controller.
# Time 4.12 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.14 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.16 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.18 [sec]: Control: [1.4142099618911743, -1.4142099618911743] is applied to the system.
# Time 4.20 [sec]: New SAC control computation is scheduled.
# Time 4.20 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.22 [sec]: New SAC control is available to the controller.
# Time 4.22 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.24 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.26 [sec]: Control: [0.28013747930526733, -3.990178346633911] is applied to the system.
# Time 4.28 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.30 [sec]: New SAC control computation is scheduled.
# Time 4.30 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.32 [sec]: New SAC control is available to the controller.
# Time 4.32 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.34 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.36 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.38 [sec]: Control: [2.0, 0.0] is applied to the system.
# Time 4.40 [sec]: New measurement is obtained.

# %%
e_state = result.w_history[end].e_state;
w = result.w_history[end];
u_schedule = result.u_schedule_history[end];
target_trajectory = result.target_trajectory_history[end];

# %%
rpf = get_robot_present_and_future(e_state, u_schedule, controller.sim_param, controller.cnt_param);

# %%
prediction_dict = sample_future_ado_positions!(controller.predictor, ado_inputs,
                                               rpf);

# %%
u_nominal_idx = 12;
prediction_dict_clipped = get_clipped_prediction_dict(prediction_dict,
                                              num_samples, u_nominal_idx)
nominal_trajectory = [rpf[u_nominal_idx, t, 1:2] for t = 1:size(rpf, 2)];
plt = visualize!(Dict(), w, target_trajectory, prediction_dict_clipped, num_samples, nominal_trajectory,
         xlim=(-3. + -5.263534, 13. + -5.314636), 
         ylim=(0. + -5.263534, 10. + -5.314636), figsize=(600, 400), 
         legendfontsize=7, legend=:bottomright, markersize=5)

# %%
u_nominal_idx = 6;
prediction_dict_clipped = get_clipped_prediction_dict(prediction_dict,
                                              num_samples, u_nominal_idx)
nominal_trajectory = [rpf[u_nominal_idx, t, 1:2] for t = 1:size(rpf, 2)];
plt = visualize!(Dict(), w, target_trajectory, prediction_dict_clipped, num_samples, nominal_trajectory,
         xlim=(-3. + -5.263534, 13. + -5.314636), 
         ylim=(0. + -5.263534, 10. + -5.314636), figsize=(600, 400), 
         legendfontsize=7, legend=:bottomright, markersize=5)
