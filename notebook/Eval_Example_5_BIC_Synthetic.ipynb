# %%
using Revise

ENV["PYCALL_JL_RUNTIME_PYTHON"] = Sys.which("python")
using FileIO
using JLD2
using RiskSensitiveSAC
# Out:
# ┌ Info: Precompiling RiskSensitiveSAC [e1fab9f6-18d5-46a3-a575-fcee50e8520a]
# └ @ Base loading.jl:1278
# ┌ Info: Number of Julia Thread(s): 1
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:39
# ┌ Info: CUDA Device: GeForce RTX 2080 Ti
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:40
# ┌ Info: Python executable used by PyCall: /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/env_trajectron++/bin/python3.6
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/RiskSensitiveSAC.jl:41

# %%
include("$(@__DIR__)/../scripts/default_params/params_synthetic_gaussian.jl");

min_dist = 0.8;  # minimum separation distance required 

include("$(@__DIR__)/../scripts/parameter_setup_bic.jl");

# %%
scene_loader, controller, w_init, measurement_schedule, target_trajectory, target_speed, predictor =
controller_setup(scene_param,
                 cost_param=cost_param,
                 cnt_param=cnt_param,
                 dtc=dtc,
                 dto=dto,
                 prediction_steps=prediction_steps,
                 num_samples=num_samples,
                 sim_rng=sim_rng,
                 ado_pos_init_dict=ado_pos_init_dict,
                 ado_vel_dict=ado_vel_dict,
                 ego_pos_init_vec=ego_pos_init_vec,
                 ego_vel_init_vec=nothing,
                 ego_pos_goal_vec=ego_pos_goal_vec,
                 target_speed=target_speed,
                 sim_horizon=sim_horizon,
                 verbose=true);
# Out:
# Scene Mode: synthetic
# BIC Controller

# %%
result, ~, ~ = evaluate(scene_loader, controller, w_init, ego_pos_goal_vec, target_speed,
                  measurement_schedule, target_trajectory, pos_error_replan, predictor=predictor);
# Out:
# ┌ Warning: Time 0.00 [sec]: BIC computation took 22.747 [sec], which exceeds the maximum computation time allowed.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/bic.jl:289
# ┌ Warning: Time 0.00 [sec]: This evaluation iteration took 0.305 [sec], which exceeds dtc.
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/evaluation.jl:254

# %%
display_log(result.log)
# Out:
# Time 0.00 [sec]: New BIC control computation is scheduled.
# Time 0.00 [sec]: New BIC control is available to the controller.
# Time 0.00 [sec]: Control: [-1.8424810113847183e-9, -3.739054729672278e-9] is applied to the system.
# Time 0.02 [sec]: Control: [-1.8424810113847183e-9, -3.739054729672278e-9] is applied to the system.
# Time 0.04 [sec]: Control: [-1.8424810113847183e-9, -3.739054729672278e-9] is applied to the system.
# Time 0.06 [sec]: Control: [-1.8424810113847183e-9, -3.739054729672278e-9] is applied to the system.
# Time 0.08 [sec]: Control: [-1.8424810113847183e-9, -3.739054729672278e-9] is applied to the system.
# Time 0.10 [sec]: New BIC control computation is scheduled.
# Time 0.10 [sec]: Control: [-1.8424810113847183e-9, -3.739054729672278e-9] is applied to the system.
# Time 0.12 [sec]: New BIC control is available to the controller.
# Time 0.12 [sec]: Control: [-0.11099685406246225, 8.360907880197283e-10] is applied to the system.
# Time 0.14 [sec]: Control: [-0.11099685406246225, 8.360907880197283e-10] is applied to the system.
# Time 0.16 [sec]: Control: [-0.11099685406246225, 8.360907880197283e-10] is applied to the system.
# Time 0.18 [sec]: Control: [-0.11099685406246225, 8.360907880197283e-10] is applied to the system.
# Time 0.20 [sec]: New BIC control computation is scheduled.
# Time 0.20 [sec]: Control: [-0.11099685406246225, 8.360907880197283e-10] is applied to the system.
# Time 0.22 [sec]: New BIC control is available to the controller.
# Time 0.22 [sec]: Control: [-0.20847486469829535, 1.896828292401713e-10] is applied to the system.
# Time 0.24 [sec]: Control: [-0.20847486469829535, 1.896828292401713e-10] is applied to the system.
# Time 0.26 [sec]: Control: [-0.20847486469829535, 1.896828292401713e-10] is applied to the system.
# Time 0.28 [sec]: Control: [-0.20847486469829535, 1.896828292401713e-10] is applied to the system.
# Time 0.30 [sec]: New BIC control computation is scheduled.
# Time 0.30 [sec]: Control: [-0.20847486469829535, 1.896828292401713e-10] is applied to the system.
# Time 0.32 [sec]: New BIC control is available to the controller.
# Time 0.32 [sec]: Control: [-0.2895920015102997, 3.352143579965453e-9] is applied to the system.
# Time 0.34 [sec]: Control: [-0.2895920015102997, 3.352143579965453e-9] is applied to the system.
# Time 0.36 [sec]: Control: [-0.2895920015102997, 3.352143579965453e-9] is applied to the system.
# Time 0.38 [sec]: Control: [-0.2895920015102997, 3.352143579965453e-9] is applied to the system.
# Time 0.40 [sec]: New measurement is obtained.
# Time 0.40 [sec]: New BIC control computation is scheduled.
# Time 0.40 [sec]: Control: [-0.2895920015102997, 3.352143579965453e-9] is applied to the system.
# Time 0.42 [sec]: New BIC control is available to the controller.
# Time 0.42 [sec]: Control: [0.08833181519840344, 3.0047009414411813e-9] is applied to the system.
# Time 0.44 [sec]: Control: [0.08833181519840344, 3.0047009414411813e-9] is applied to the system.
# Time 0.46 [sec]: Control: [0.08833181519840344, 3.0047009414411813e-9] is applied to the system.
# Time 0.48 [sec]: Control: [0.08833181519840344, 3.0047009414411813e-9] is applied to the system.
# Time 0.50 [sec]: New BIC control computation is scheduled.
# Time 0.50 [sec]: Control: [0.08833181519840344, 3.0047009414411813e-9] is applied to the system.
# Time 0.52 [sec]: New BIC control is available to the controller.
# Time 0.52 [sec]: Control: [-0.01816671748100839, 2.481521231438451e-9] is applied to the system.
# Time 0.54 [sec]: Control: [-0.01816671748100839, 2.481521231438451e-9] is applied to the system.
# Time 0.56 [sec]: Control: [-0.01816671748100839, 2.481521231438451e-9] is applied to the system.
# Time 0.58 [sec]: Control: [-0.01816671748100839, 2.481521231438451e-9] is applied to the system.
# Time 0.60 [sec]: New BIC control computation is scheduled.
# Time 0.60 [sec]: Control: [-0.01816671748100839, 2.481521231438451e-9] is applied to the system.
# Time 0.62 [sec]: New BIC control is available to the controller.
# Time 0.62 [sec]: Control: [-0.1237625497043326, 1.0976964684706496e-9] is applied to the system.
# Time 0.64 [sec]: Control: [-0.1237625497043326, 1.0976964684706496e-9] is applied to the system.
# Time 0.66 [sec]: Control: [-0.1237625497043326, 1.0976964684706496e-9] is applied to the system.
# Time 0.68 [sec]: Control: [-0.1237625497043326, 1.0976964684706496e-9] is applied to the system.
# Time 0.70 [sec]: New BIC control computation is scheduled.
# Time 0.70 [sec]: Control: [-0.1237625497043326, 1.0976964684706496e-9] is applied to the system.
# Time 0.72 [sec]: New BIC control is available to the controller.
# Time 0.72 [sec]: Control: [-0.21317115850829818, -1.0088565014377616e-9] is applied to the system.
# Time 0.74 [sec]: Control: [-0.21317115850829818, -1.0088565014377616e-9] is applied to the system.
# Time 0.76 [sec]: Control: [-0.21317115850829818, -1.0088565014377616e-9] is applied to the system.
# Time 0.78 [sec]: Control: [-0.21317115850829818, -1.0088565014377616e-9] is applied to the system.
# Time 0.80 [sec]: New measurement is obtained.
# Time 0.80 [sec]: New BIC control computation is scheduled.
# Time 0.80 [sec]: Control: [-0.21317115850829818, -1.0088565014377616e-9] is applied to the system.
# Time 0.82 [sec]: New BIC control is available to the controller.
# Time 0.82 [sec]: Control: [0.15676893708307862, 6.497520925876e-10] is applied to the system.
# Time 0.84 [sec]: Control: [0.15676893708307862, 6.497520925876e-10] is applied to the system.
# Time 0.86 [sec]: Control: [0.15676893708307862, 6.497520925876e-10] is applied to the system.
# Time 0.88 [sec]: Control: [0.15676893708307862, 6.497520925876e-10] is applied to the system.
# Time 0.90 [sec]: New BIC control computation is scheduled.
# Time 0.90 [sec]: Control: [0.15676893708307862, 6.497520925876e-10] is applied to the system.
# Time 0.92 [sec]: New BIC control is available to the controller.
# Time 0.92 [sec]: Control: [0.04265406390336748, -1.9580803548165172e-9] is applied to the system.
# Time 0.94 [sec]: Control: [0.04265406390336748, -1.9580803548165172e-9] is applied to the system.
# Time 0.96 [sec]: Control: [0.04265406390336748, -1.9580803548165172e-9] is applied to the system.
# Time 0.98 [sec]: Control: [0.04265406390336748, -1.9580803548165172e-9] is applied to the system.
# Time 1.00 [sec]: New BIC control computation is scheduled.
# Time 1.00 [sec]: Control: [0.04265406390336748, -1.9580803548165172e-9] is applied to the system.
# Time 1.02 [sec]: New BIC control is available to the controller.
# Time 1.02 [sec]: Control: [-0.07015586675567016, 3.431364794257208e-10] is applied to the system.
# Time 1.04 [sec]: Control: [-0.07015586675567016, 3.431364794257208e-10] is applied to the system.
# Time 1.06 [sec]: Control: [-0.07015586675567016, 3.431364794257208e-10] is applied to the system.
# Time 1.08 [sec]: Control: [-0.07015586675567016, 3.431364794257208e-10] is applied to the system.
# Time 1.10 [sec]: New BIC control computation is scheduled.
# Time 1.10 [sec]: Control: [-0.07015586675567016, 3.431364794257208e-10] is applied to the system.
# Time 1.12 [sec]: New BIC control is available to the controller.
# Time 1.12 [sec]: Control: [-0.16635157656907834, 1.049207559909333e-9] is applied to the system.
# Time 1.14 [sec]: Control: [-0.16635157656907834, 1.049207559909333e-9] is applied to the system.
# Time 1.16 [sec]: Control: [-0.16635157656907834, 1.049207559909333e-9] is applied to the system.
# Time 1.18 [sec]: Control: [-0.16635157656907834, 1.049207559909333e-9] is applied to the system.
# Time 1.20 [sec]: New measurement is obtained.
# Time 1.20 [sec]: New BIC control computation is scheduled.
# Time 1.20 [sec]: Control: [-0.16635157656907834, 1.049207559909333e-9] is applied to the system.
# Time 1.22 [sec]: New BIC control is available to the controller.
# Time 1.22 [sec]: Control: [0.19724465671700736, -1.2102972187407406e-8] is applied to the system.
# Time 1.24 [sec]: Control: [0.19724465671700736, -1.2102972187407406e-8] is applied to the system.
# Time 1.26 [sec]: Control: [0.19724465671700736, -1.2102972187407406e-8] is applied to the system.
# Time 1.28 [sec]: Control: [0.19724465671700736, -1.2102972187407406e-8] is applied to the system.
# Time 1.30 [sec]: New BIC control computation is scheduled.
# Time 1.30 [sec]: Control: [0.19724465671700736, -1.2102972187407406e-8] is applied to the system.
# Time 1.32 [sec]: New BIC control is available to the controller.
# Time 1.32 [sec]: Control: [0.07723807012943062, 4.393135095978105e-9] is applied to the system.
# Time 1.34 [sec]: Control: [0.07723807012943062, 4.393135095978105e-9] is applied to the system.
# Time 1.36 [sec]: Control: [0.07723807012943062, 4.393135095978105e-9] is applied to the system.
# Time 1.38 [sec]: Control: [0.07723807012943062, 4.393135095978105e-9] is applied to the system.
# Time 1.40 [sec]: New BIC control computation is scheduled.
# Time 1.40 [sec]: Control: [0.07723807012943062, 4.393135095978105e-9] is applied to the system.
# Time 1.42 [sec]: New BIC control is available to the controller.
# Time 1.42 [sec]: Control: [-0.04100916333208532, 4.5370581233455854e-10] is applied to the system.
# Time 1.44 [sec]: Control: [-0.04100916333208532, 4.5370581233455854e-10] is applied to the system.
# Time 1.46 [sec]: Control: [-0.04100916333208532, 4.5370581233455854e-10] is applied to the system.
# Time 1.48 [sec]: Control: [-0.04100916333208532, 4.5370581233455854e-10] is applied to the system.
# Time 1.50 [sec]: New BIC control computation is scheduled.
# Time 1.50 [sec]: Control: [-0.04100916333208532, 4.5370581233455854e-10] is applied to the system.
# Time 1.52 [sec]: New BIC control is available to the controller.
# Time 1.52 [sec]: Control: [-0.142190962920091, 2.2609633310549268e-9] is applied to the system.
# Time 1.54 [sec]: Control: [-0.142190962920091, 2.2609633310549268e-9] is applied to the system.
# Time 1.56 [sec]: Control: [-0.142190962920091, 2.2609633310549268e-9] is applied to the system.
# Time 1.58 [sec]: Control: [-0.142190962920091, 2.2609633310549268e-9] is applied to the system.
# Time 1.60 [sec]: New measurement is obtained.
# Time 1.60 [sec]: New BIC control computation is scheduled.
# Time 1.60 [sec]: Control: [-0.142190962920091, 2.2609633310549268e-9] is applied to the system.
# Time 1.62 [sec]: New BIC control is available to the controller.
# Time 1.62 [sec]: Control: [0.2168625009543418, -4.334971120117433e-9] is applied to the system.
# Time 1.64 [sec]: Control: [0.2168625009543418, -4.334971120117433e-9] is applied to the system.
# Time 1.66 [sec]: Control: [0.2168625009543418, -4.334971120117433e-9] is applied to the system.
# Time 1.68 [sec]: Control: [0.2168625009543418, -4.334971120117433e-9] is applied to the system.
# Time 1.70 [sec]: New BIC control computation is scheduled.
# Time 1.70 [sec]: Control: [0.2168625009543418, -4.334971120117433e-9] is applied to the system.
# Time 1.72 [sec]: New BIC control is available to the controller.
# Time 1.72 [sec]: Control: [0.09274448362001715, 4.1517316280904315e-10] is applied to the system.
# Time 1.74 [sec]: Control: [0.09274448362001715, 4.1517316280904315e-10] is applied to the system.
# Time 1.76 [sec]: Control: [0.09274448362001715, 4.1517316280904315e-10] is applied to the system.
# Time 1.78 [sec]: Control: [0.09274448362001715, 4.1517316280904315e-10] is applied to the system.
# Time 1.80 [sec]: New BIC control computation is scheduled.
# Time 1.80 [sec]: Control: [0.09274448362001715, 4.1517316280904315e-10] is applied to the system.
# Time 1.82 [sec]: New BIC control is available to the controller.
# Time 1.82 [sec]: Control: [-0.029197896339017912, 2.2379820361664505e-8] is applied to the system.
# Time 1.84 [sec]: Control: [-0.029197896339017912, 2.2379820361664505e-8] is applied to the system.
# Time 1.86 [sec]: Control: [-0.029197896339017912, 2.2379820361664505e-8] is applied to the system.
# Time 1.88 [sec]: Control: [-0.029197896339017912, 2.2379820361664505e-8] is applied to the system.
# Time 1.90 [sec]: New BIC control computation is scheduled.
# Time 1.90 [sec]: Control: [-0.029197896339017912, 2.2379820361664505e-8] is applied to the system.
# Time 1.92 [sec]: New BIC control is available to the controller.
# Time 1.92 [sec]: Control: [-0.1336762373470111, 7.443465007736665e-9] is applied to the system.
# Time 1.94 [sec]: Control: [-0.1336762373470111, 7.443465007736665e-9] is applied to the system.
# Time 1.96 [sec]: Control: [-0.1336762373470111, 7.443465007736665e-9] is applied to the system.
# Time 1.98 [sec]: Control: [-0.1336762373470111, 7.443465007736665e-9] is applied to the system.
# Time 2.00 [sec]: New measurement is obtained.
# Time 2.00 [sec]: New BIC control computation is scheduled.
# Time 2.00 [sec]: Control: [-0.1336762373470111, 7.443465007736665e-9] is applied to the system.
# Time 2.02 [sec]: New BIC control is available to the controller.
# Time 2.02 [sec]: Control: [0.22245946531248673, -5.746207786304515e-9] is applied to the system.
# Time 2.04 [sec]: Control: [0.22245946531248673, -5.746207786304515e-9] is applied to the system.
# Time 2.06 [sec]: Control: [0.22245946531248673, -5.746207786304515e-9] is applied to the system.
# Time 2.08 [sec]: Control: [0.22245946531248673, -5.746207786304515e-9] is applied to the system.
# Time 2.10 [sec]: New BIC control computation is scheduled.
# Time 2.10 [sec]: Control: [0.22245946531248673, -5.746207786304515e-9] is applied to the system.
# Time 2.12 [sec]: New BIC control is available to the controller.
# Time 2.12 [sec]: Control: [0.09578114976869485, -1.49580679996696e-7] is applied to the system.
# Time 2.14 [sec]: Control: [0.09578114976869485, -1.49580679996696e-7] is applied to the system.
# Time 2.16 [sec]: Control: [0.09578114976869485, -1.49580679996696e-7] is applied to the system.
# Time 2.18 [sec]: Control: [0.09578114976869485, -1.49580679996696e-7] is applied to the system.
# Time 2.20 [sec]: New BIC control computation is scheduled.
# Time 2.20 [sec]: Control: [0.09578114976869485, -1.49580679996696e-7] is applied to the system.
# Time 2.22 [sec]: New BIC control is available to the controller.
# Time 2.22 [sec]: Control: [-0.028385960556551446, 1.561583741055662e-8] is applied to the system.
# Time 2.24 [sec]: Control: [-0.028385960556551446, 1.561583741055662e-8] is applied to the system.
# Time 2.26 [sec]: Control: [-0.028385960556551446, 1.561583741055662e-8] is applied to the system.
# Time 2.28 [sec]: Control: [-0.028385960556551446, 1.561583741055662e-8] is applied to the system.
# Time 2.30 [sec]: New BIC control computation is scheduled.
# Time 2.30 [sec]: Control: [-0.028385960556551446, 1.561583741055662e-8] is applied to the system.
# Time 2.32 [sec]: New BIC control is available to the controller.
# Time 2.32 [sec]: Control: [-0.13477685917070722, 6.844605237489302e-8] is applied to the system.
# Time 2.34 [sec]: Control: [-0.13477685917070722, 6.844605237489302e-8] is applied to the system.
# Time 2.36 [sec]: Control: [-0.13477685917070722, 6.844605237489302e-8] is applied to the system.
# Time 2.38 [sec]: Control: [-0.13477685917070722, 6.844605237489302e-8] is applied to the system.
# Time 2.40 [sec]: New measurement is obtained.
# Time 2.40 [sec]: New BIC control computation is scheduled.
# Time 2.40 [sec]: Control: [-0.13477685917070722, 6.844605237489302e-8] is applied to the system.
# Time 2.42 [sec]: New BIC control is available to the controller.
# Time 2.42 [sec]: Control: [0.21973557562019422, 1.1187930572004972e-8] is applied to the system.
# Time 2.44 [sec]: Control: [0.21973557562019422, 1.1187930572004972e-8] is applied to the system.
# Time 2.46 [sec]: Control: [0.21973557562019422, 1.1187930572004972e-8] is applied to the system.
# Time 2.48 [sec]: Control: [0.21973557562019422, 1.1187930572004972e-8] is applied to the system.
# Time 2.50 [sec]: New BIC control computation is scheduled.
# Time 2.50 [sec]: Control: [0.21973557562019422, 1.1187930572004972e-8] is applied to the system.
# Time 2.52 [sec]: New BIC control is available to the controller.
# Time 2.52 [sec]: Control: [0.09170011256530267, 7.875710365900708e-9] is applied to the system.
# Time 2.54 [sec]: Control: [0.09170011256530267, 7.875710365900708e-9] is applied to the system.
# Time 2.56 [sec]: Control: [0.09170011256530267, 7.875710365900708e-9] is applied to the system.
# Time 2.58 [sec]: Control: [0.09170011256530267, 7.875710365900708e-9] is applied to the system.
# Time 2.60 [sec]: New BIC control computation is scheduled.
# Time 2.60 [sec]: Control: [0.09170011256530267, 7.875710365900708e-9] is applied to the system.
# Time 2.62 [sec]: New BIC control is available to the controller.
# Time 2.62 [sec]: Control: [-0.033581234442413836, 5.715610477347365e-10] is applied to the system.
# Time 2.64 [sec]: Control: [-0.033581234442413836, 5.715610477347365e-10] is applied to the system.
# Time 2.66 [sec]: Control: [-0.033581234442413836, 5.715610477347365e-10] is applied to the system.
# Time 2.68 [sec]: Control: [-0.033581234442413836, 5.715610477347365e-10] is applied to the system.
# Time 2.70 [sec]: New BIC control computation is scheduled.
# Time 2.70 [sec]: Control: [-0.033581234442413836, 5.715610477347365e-10] is applied to the system.
# Time 2.72 [sec]: New BIC control is available to the controller.
# Time 2.72 [sec]: Control: [-0.14086539062996134, 7.481303018568592e-9] is applied to the system.
# Time 2.74 [sec]: Control: [-0.14086539062996134, 7.481303018568592e-9] is applied to the system.
# Time 2.76 [sec]: Control: [-0.14086539062996134, 7.481303018568592e-9] is applied to the system.
# Time 2.78 [sec]: Control: [-0.14086539062996134, 7.481303018568592e-9] is applied to the system.
# Time 2.80 [sec]: New measurement is obtained.
# Time 2.80 [sec]: New BIC control computation is scheduled.
# Time 2.80 [sec]: Control: [-0.14086539062996134, 7.481303018568592e-9] is applied to the system.
# Time 2.82 [sec]: New BIC control is available to the controller.
# Time 2.82 [sec]: Control: [0.2129528711532552, 5.159820210339802e-9] is applied to the system.
# Time 2.84 [sec]: Control: [0.2129528711532552, 5.159820210339802e-9] is applied to the system.
# Time 2.86 [sec]: Control: [0.2129528711532552, 5.159820210339802e-9] is applied to the system.
# Time 2.88 [sec]: Control: [0.2129528711532552, 5.159820210339802e-9] is applied to the system.
# Time 2.90 [sec]: New BIC control computation is scheduled.
# Time 2.90 [sec]: Control: [0.2129528711532552, 5.159820210339802e-9] is applied to the system.
# Time 2.92 [sec]: New BIC control is available to the controller.
# Time 2.92 [sec]: Control: [0.08440159687922624, 7.309203094687615e-10] is applied to the system.
# Time 2.94 [sec]: Control: [0.08440159687922624, 7.309203094687615e-10] is applied to the system.
# Time 2.96 [sec]: Control: [0.08440159687922624, 7.309203094687615e-10] is applied to the system.
# Time 2.98 [sec]: Control: [0.08440159687922624, 7.309203094687615e-10] is applied to the system.
# Time 3.00 [sec]: New BIC control computation is scheduled.
# Time 3.00 [sec]: Control: [0.08440159687922624, 7.309203094687615e-10] is applied to the system.
# Time 3.02 [sec]: New BIC control is available to the controller.
# Time 3.02 [sec]: Control: [-0.041237075208870676, 6.007215477504805e-9] is applied to the system.
# Time 3.04 [sec]: Control: [-0.041237075208870676, 6.007215477504805e-9] is applied to the system.
# Time 3.06 [sec]: Control: [-0.041237075208870676, 6.007215477504805e-9] is applied to the system.
# Time 3.08 [sec]: Control: [-0.041237075208870676, 6.007215477504805e-9] is applied to the system.
# Time 3.10 [sec]: New BIC control computation is scheduled.
# Time 3.10 [sec]: Control: [-0.041237075208870676, 6.007215477504805e-9] is applied to the system.
# Time 3.12 [sec]: New BIC control is available to the controller.
# Time 3.12 [sec]: Control: [-0.14873890764584713, 4.523153338039393e-9] is applied to the system.
# Time 3.14 [sec]: Control: [-0.14873890764584713, 4.523153338039393e-9] is applied to the system.
# Time 3.16 [sec]: Control: [-0.14873890764584713, 4.523153338039393e-9] is applied to the system.
# Time 3.18 [sec]: Control: [-0.14873890764584713, 4.523153338039393e-9] is applied to the system.
# Time 3.20 [sec]: New measurement is obtained.
# Time 3.20 [sec]: New BIC control computation is scheduled.
# Time 3.20 [sec]: Control: [-0.14873890764584713, 4.523153338039393e-9] is applied to the system.
# Time 3.22 [sec]: New BIC control is available to the controller.
# Time 3.22 [sec]: Control: [0.20498365925217846, 5.383443548309701e-10] is applied to the system.
# Time 3.24 [sec]: Control: [0.20498365925217846, 5.383443548309701e-10] is applied to the system.
# Time 3.26 [sec]: Control: [0.20498365925217846, 5.383443548309701e-10] is applied to the system.
# Time 3.28 [sec]: Control: [0.20498365925217846, 5.383443548309701e-10] is applied to the system.
# Time 3.30 [sec]: New BIC control computation is scheduled.
# Time 3.30 [sec]: Control: [0.20498365925217846, 5.383443548309701e-10] is applied to the system.
# Time 3.32 [sec]: New BIC control is available to the controller.
# Time 3.32 [sec]: Control: [0.07644213329927442, 2.487880010704441e-9] is applied to the system.
# Time 3.34 [sec]: Control: [0.07644213329927442, 2.487880010704441e-9] is applied to the system.
# Time 3.36 [sec]: Control: [0.07644213329927442, 2.487880010704441e-9] is applied to the system.
# Time 3.38 [sec]: Control: [0.07644213329927442, 2.487880010704441e-9] is applied to the system.
# Time 3.40 [sec]: New BIC control computation is scheduled.
# Time 3.40 [sec]: Control: [0.07644213329927442, 2.487880010704441e-9] is applied to the system.
# Time 3.42 [sec]: New BIC control is available to the controller.
# Time 3.42 [sec]: Control: [-0.0490967268756446, 2.9742057252504584e-9] is applied to the system.
# Time 3.44 [sec]: Control: [-0.0490967268756446, 2.9742057252504584e-9] is applied to the system.
# Time 3.46 [sec]: Control: [-0.0490967268756446, 2.9742057252504584e-9] is applied to the system.
# Time 3.48 [sec]: Control: [-0.0490967268756446, 2.9742057252504584e-9] is applied to the system.
# Time 3.50 [sec]: New BIC control computation is scheduled.
# Time 3.50 [sec]: Control: [-0.0490967268756446, 2.9742057252504584e-9] is applied to the system.
# Time 3.52 [sec]: New BIC control is available to the controller.
# Time 3.52 [sec]: Control: [-0.15642298223127907, -2.880805605028262e-7] is applied to the system.
# Time 3.54 [sec]: Control: [-0.15642298223127907, -2.880805605028262e-7] is applied to the system.
# Time 3.56 [sec]: Control: [-0.15642298223127907, -2.880805605028262e-7] is applied to the system.
# Time 3.58 [sec]: Control: [-0.15642298223127907, -2.880805605028262e-7] is applied to the system.
# Time 3.60 [sec]: New measurement is obtained.
# Time 3.60 [sec]: New BIC control computation is scheduled.
# Time 3.60 [sec]: Control: [-0.15642298223127907, -2.880805605028262e-7] is applied to the system.
# Time 3.62 [sec]: New BIC control is available to the controller.
# Time 3.62 [sec]: Control: [0.19753838656215938, 3.8128809900797264e-8] is applied to the system.
# Time 3.64 [sec]: Control: [0.19753838656215938, 3.8128809900797264e-8] is applied to the system.
# Time 3.66 [sec]: Control: [0.19753838656215938, 3.8128809900797264e-8] is applied to the system.
# Time 3.68 [sec]: Control: [0.19753838656215938, 3.8128809900797264e-8] is applied to the system.
# Time 3.70 [sec]: New BIC control computation is scheduled.
# Time 3.70 [sec]: Control: [0.19753838656215938, 3.8128809900797264e-8] is applied to the system.
# Time 3.72 [sec]: New BIC control is available to the controller.
# Time 3.72 [sec]: Control: [0.06928656023029256, 4.7483550234306e-8] is applied to the system.
# Time 3.74 [sec]: Control: [0.06928656023029256, 4.7483550234306e-8] is applied to the system.
# Time 3.76 [sec]: Control: [0.06928656023029256, 4.7483550234306e-8] is applied to the system.
# Time 3.78 [sec]: Control: [0.06928656023029256, 4.7483550234306e-8] is applied to the system.
# Time 3.80 [sec]: New BIC control computation is scheduled.
# Time 3.80 [sec]: Control: [0.06928656023029256, 4.7483550234306e-8] is applied to the system.
# Time 3.82 [sec]: New BIC control is available to the controller.
# Time 3.82 [sec]: Control: [-0.05592224809600457, 4.1493821053718406e-8] is applied to the system.
# Time 3.84 [sec]: Control: [-0.05592224809600457, 4.1493821053718406e-8] is applied to the system.
# Time 3.86 [sec]: Control: [-0.05592224809600457, 4.1493821053718406e-8] is applied to the system.
# Time 3.88 [sec]: Control: [-0.05592224809600457, 4.1493821053718406e-8] is applied to the system.
# Time 3.90 [sec]: New BIC control computation is scheduled.
# Time 3.90 [sec]: Control: [-0.05592224809600457, 4.1493821053718406e-8] is applied to the system.
# Time 3.92 [sec]: New BIC control is available to the controller.
# Time 3.92 [sec]: Control: [-0.16288759466356456, 1.3111791129069905e-7] is applied to the system.
# Time 3.94 [sec]: Control: [-0.16288759466356456, 1.3111791129069905e-7] is applied to the system.
# Time 3.96 [sec]: Control: [-0.16288759466356456, 1.3111791129069905e-7] is applied to the system.
# Time 3.98 [sec]: Control: [-0.16288759466356456, 1.3111791129069905e-7] is applied to the system.
# Time 4.00 [sec]: New measurement is obtained.
# Time 4.00 [sec]: New BIC control computation is scheduled.
# Time 4.00 [sec]: Control: [-0.16288759466356456, 1.3111791129069905e-7] is applied to the system.
# Time 4.02 [sec]: New BIC control is available to the controller.
# Time 4.02 [sec]: Control: [0.19145654607835164, 2.009393804283097e-8] is applied to the system.
# Time 4.04 [sec]: Control: [0.19145654607835164, 2.009393804283097e-8] is applied to the system.
# Time 4.06 [sec]: Control: [0.19145654607835164, 2.009393804283097e-8] is applied to the system.
# Time 4.08 [sec]: Control: [0.19145654607835164, 2.009393804283097e-8] is applied to the system.
# Time 4.10 [sec]: New BIC control computation is scheduled.
# Time 4.10 [sec]: Control: [0.19145654607835164, 2.009393804283097e-8] is applied to the system.
# Time 4.12 [sec]: New BIC control is available to the controller.
# Time 4.12 [sec]: Control: [0.06360217008284023, 1.489562062602957e-8] is applied to the system.
# Time 4.14 [sec]: Control: [0.06360217008284023, 1.489562062602957e-8] is applied to the system.
# Time 4.16 [sec]: Control: [0.06360217008284023, 1.489562062602957e-8] is applied to the system.
# Time 4.18 [sec]: Control: [0.06360217008284023, 1.489562062602957e-8] is applied to the system.
# Time 4.20 [sec]: New BIC control computation is scheduled.
# Time 4.20 [sec]: Control: [0.06360217008284023, 1.489562062602957e-8] is applied to the system.
# Time 4.22 [sec]: New BIC control is available to the controller.
# Time 4.22 [sec]: Control: [-0.2242183433894325, 0.16913014374654542] is applied to the system.
# Time 4.24 [sec]: Control: [-0.2242183433894325, 0.16913014374654542] is applied to the system.
# Time 4.26 [sec]: Control: [-0.2242183433894325, 0.16913014374654542] is applied to the system.
# Time 4.28 [sec]: Control: [-0.2242183433894325, 0.16913014374654542] is applied to the system.
# Time 4.30 [sec]: New BIC control computation is scheduled.
# Time 4.30 [sec]: Control: [-0.2242183433894325, 0.16913014374654542] is applied to the system.
# Time 4.32 [sec]: New BIC control is available to the controller.
# Time 4.32 [sec]: Control: [-0.39949511852509856, 0.25952232018866206] is applied to the system.
# Time 4.34 [sec]: Control: [-0.39949511852509856, 0.25952232018866206] is applied to the system.
# Time 4.36 [sec]: Control: [-0.39949511852509856, 0.25952232018866206] is applied to the system.
# Time 4.38 [sec]: Control: [-0.39949511852509856, 0.25952232018866206] is applied to the system.
# Time 4.40 [sec]: New measurement is obtained.
# Time 4.40 [sec]: New BIC control computation is scheduled.
# Time 4.40 [sec]: Control: [-0.39949511852509856, 0.25952232018866206] is applied to the system.
# Time 4.42 [sec]: New BIC control is available to the controller.
# Time 4.42 [sec]: Control: [-3.27177949973202, 2.4400417124496543] is applied to the system.
# Time 4.44 [sec]: Control: [-3.27177949973202, 2.4400417124496543] is applied to the system.
# Time 4.46 [sec]: Control: [-3.27177949973202, 2.4400417124496543] is applied to the system.
# Time 4.48 [sec]: Control: [-3.27177949973202, 2.4400417124496543] is applied to the system.
# Time 4.50 [sec]: New BIC control computation is scheduled.
# Time 4.50 [sec]: Control: [-3.27177949973202, 2.4400417124496543] is applied to the system.
# Time 4.52 [sec]: New BIC control is available to the controller.
# Time 4.52 [sec]: Control: [-2.018128467174385, 1.6917839145491307] is applied to the system.
# Time 4.54 [sec]: Control: [-2.018128467174385, 1.6917839145491307] is applied to the system.
# Time 4.56 [sec]: Control: [-2.018128467174385, 1.6917839145491307] is applied to the system.
# Time 4.58 [sec]: Control: [-2.018128467174385, 1.6917839145491307] is applied to the system.
# Time 4.60 [sec]: New BIC control computation is scheduled.
# Time 4.60 [sec]: Control: [-2.018128467174385, 1.6917839145491307] is applied to the system.
# Time 4.62 [sec]: New BIC control is available to the controller.
# Time 4.62 [sec]: Control: [-0.7786002577196195, 0.7977775170448449] is applied to the system.
# Time 4.64 [sec]: Control: [-0.7786002577196195, 0.7977775170448449] is applied to the system.
# Time 4.66 [sec]: Control: [-0.7786002577196195, 0.7977775170448449] is applied to the system.
# Time 4.68 [sec]: Control: [-0.7786002577196195, 0.7977775170448449] is applied to the system.
# Time 4.70 [sec]: New BIC control computation is scheduled.
# Time 4.70 [sec]: Control: [-0.7786002577196195, 0.7977775170448449] is applied to the system.
# Time 4.72 [sec]: New BIC control is available to the controller.
# Time 4.72 [sec]: Control: [-0.05623969365582722, 0.16992673505456898] is applied to the system.
# Time 4.74 [sec]: Control: [-0.05623969365582722, 0.16992673505456898] is applied to the system.
# Time 4.76 [sec]: Control: [-0.05623969365582722, 0.16992673505456898] is applied to the system.
# Time 4.78 [sec]: Control: [-0.05623969365582722, 0.16992673505456898] is applied to the system.
# Time 4.80 [sec]: New measurement is obtained.
# Time 4.80 [sec]: New BIC control computation is scheduled.
# Time 4.80 [sec]: Control: [-0.05623969365582722, 0.16992673505456898] is applied to the system.
# Time 4.82 [sec]: New BIC control is available to the controller.
# Time 4.82 [sec]: Control: [-3.075260839338731, -3.4246273973288144] is applied to the system.
# Time 4.84 [sec]: Control: [-3.075260839338731, -3.4246273973288144] is applied to the system.
# Time 4.86 [sec]: Control: [-3.075260839338731, -3.4246273973288144] is applied to the system.
# Time 4.88 [sec]: Control: [-3.075260839338731, -3.4246273973288144] is applied to the system.
# Time 4.90 [sec]: New BIC control computation is scheduled.
# Time 4.90 [sec]: Control: [-3.075260839338731, -3.4246273973288144] is applied to the system.
# Time 4.92 [sec]: New BIC control is available to the controller.
# Time 4.92 [sec]: Control: [-1.990227478573921, -2.375415458488521] is applied to the system.
# Time 4.94 [sec]: Control: [-1.990227478573921, -2.375415458488521] is applied to the system.
# Time 4.96 [sec]: Control: [-1.990227478573921, -2.375415458488521] is applied to the system.
# Time 4.98 [sec]: Control: [-1.990227478573921, -2.375415458488521] is applied to the system.
# Time 5.00 [sec]: New BIC control computation is scheduled.
# Time 5.00 [sec]: Control: [-1.990227478573921, -2.375415458488521] is applied to the system.
# Time 5.02 [sec]: New BIC control is available to the controller.
# Time 5.02 [sec]: Control: [-0.7595999777562698, -1.4777397230712306] is applied to the system.
# Time 5.04 [sec]: Control: [-0.7595999777562698, -1.4777397230712306] is applied to the system.
# Time 5.06 [sec]: Control: [-0.7595999777562698, -1.4777397230712306] is applied to the system.
# Time 5.08 [sec]: Control: [-0.7595999777562698, -1.4777397230712306] is applied to the system.
# Time 5.10 [sec]: New BIC control computation is scheduled.
# Time 5.10 [sec]: Control: [-0.7595999777562698, -1.4777397230712306] is applied to the system.
# Time 5.12 [sec]: New BIC control is available to the controller.
# Time 5.12 [sec]: Control: [0.00765290687293557, -0.9636570292339811] is applied to the system.
# Time 5.14 [sec]: Control: [0.00765290687293557, -0.9636570292339811] is applied to the system.
# Time 5.16 [sec]: Control: [0.00765290687293557, -0.9636570292339811] is applied to the system.
# Time 5.18 [sec]: Control: [0.00765290687293557, -0.9636570292339811] is applied to the system.
# Time 5.20 [sec]: New measurement is obtained.
# Time 5.20 [sec]: New BIC control computation is scheduled.
# Time 5.20 [sec]: Control: [0.00765290687293557, -0.9636570292339811] is applied to the system.
# Time 5.22 [sec]: New BIC control is available to the controller.
# Time 5.22 [sec]: Control: [2.1611201503214477, -0.34456947494881435] is applied to the system.
# Time 5.24 [sec]: Control: [2.1611201503214477, -0.34456947494881435] is applied to the system.
# Time 5.26 [sec]: Control: [2.1611201503214477, -0.34456947494881435] is applied to the system.
# Time 5.28 [sec]: Control: [2.1611201503214477, -0.34456947494881435] is applied to the system.
# Time 5.30 [sec]: New BIC control computation is scheduled.
# Time 5.30 [sec]: Control: [2.1611201503214477, -0.34456947494881435] is applied to the system.
# Time 5.32 [sec]: New BIC control is available to the controller.
# Time 5.32 [sec]: Control: [1.8304674788316915, -0.343506938352579] is applied to the system.
# Time 5.34 [sec]: Control: [1.8304674788316915, -0.343506938352579] is applied to the system.
# Time 5.36 [sec]: Control: [1.8304674788316915, -0.343506938352579] is applied to the system.
# Time 5.38 [sec]: Control: [1.8304674788316915, -0.343506938352579] is applied to the system.
# Time 5.40 [sec]: New BIC control computation is scheduled.
# Time 5.40 [sec]: Control: [1.8304674788316915, -0.343506938352579] is applied to the system.
# Time 5.42 [sec]: New BIC control is available to the controller.
# Time 5.42 [sec]: Control: [1.4072783775201838, -0.4270899100764446] is applied to the system.
# Time 5.44 [sec]: Control: [1.4072783775201838, -0.4270899100764446] is applied to the system.
# Time 5.46 [sec]: Control: [1.4072783775201838, -0.4270899100764446] is applied to the system.
# Time 5.48 [sec]: Control: [1.4072783775201838, -0.4270899100764446] is applied to the system.
# Time 5.50 [sec]: New BIC control computation is scheduled.
# Time 5.50 [sec]: Control: [1.4072783775201838, -0.4270899100764446] is applied to the system.
# Time 5.52 [sec]: New BIC control is available to the controller.
# Time 5.52 [sec]: Control: [1.1356060992331443, -0.4135479843895262] is applied to the system.
# Time 5.54 [sec]: Control: [1.1356060992331443, -0.4135479843895262] is applied to the system.
# Time 5.56 [sec]: Control: [1.1356060992331443, -0.4135479843895262] is applied to the system.
# Time 5.58 [sec]: Control: [1.1356060992331443, -0.4135479843895262] is applied to the system.
# Time 5.60 [sec]: New measurement is obtained.
# Time 5.60 [sec]: New BIC control computation is scheduled.
# Time 5.60 [sec]: Control: [1.1356060992331443, -0.4135479843895262] is applied to the system.
# Time 5.62 [sec]: New BIC control is available to the controller.
# Time 5.62 [sec]: Control: [2.175569110447441, 0.5624329746559562] is applied to the system.
# Time 5.64 [sec]: Control: [2.175569110447441, 0.5624329746559562] is applied to the system.
# Time 5.66 [sec]: Control: [2.175569110447441, 0.5624329746559562] is applied to the system.
# Time 5.68 [sec]: Control: [2.175569110447441, 0.5624329746559562] is applied to the system.
# Time 5.70 [sec]: New BIC control computation is scheduled.
# Time 5.70 [sec]: Control: [2.175569110447441, 0.5624329746559562] is applied to the system.
# Time 5.72 [sec]: New BIC control is available to the controller.
# Time 5.72 [sec]: Control: [1.8320796116259555, 0.553149045044127] is applied to the system.
# Time 5.74 [sec]: Control: [1.8320796116259555, 0.553149045044127] is applied to the system.
# Time 5.76 [sec]: Control: [1.8320796116259555, 0.553149045044127] is applied to the system.
# Time 5.78 [sec]: Control: [1.8320796116259555, 0.553149045044127] is applied to the system.
# Time 5.80 [sec]: New BIC control computation is scheduled.
# Time 5.80 [sec]: Control: [1.8320796116259555, 0.553149045044127] is applied to the system.
# Time 5.82 [sec]: New BIC control is available to the controller.
# Time 5.82 [sec]: Control: [1.4757660340461225, 0.5101189582447491] is applied to the system.
# Time 5.84 [sec]: Control: [1.4757660340461225, 0.5101189582447491] is applied to the system.
# Time 5.86 [sec]: Control: [1.4757660340461225, 0.5101189582447491] is applied to the system.
# Time 5.88 [sec]: Control: [1.4757660340461225, 0.5101189582447491] is applied to the system.
# Time 5.90 [sec]: New BIC control computation is scheduled.
# Time 5.90 [sec]: Control: [1.4757660340461225, 0.5101189582447491] is applied to the system.
# Time 5.92 [sec]: New BIC control is available to the controller.
# Time 5.92 [sec]: Control: [1.152591674101208, 0.4664623120954221] is applied to the system.
# Time 5.94 [sec]: Control: [1.152591674101208, 0.4664623120954221] is applied to the system.
# Time 5.96 [sec]: Control: [1.152591674101208, 0.4664623120954221] is applied to the system.
# Time 5.98 [sec]: Control: [1.152591674101208, 0.4664623120954221] is applied to the system.
# Time 6.00 [sec]: New measurement is obtained.
# Time 6.00 [sec]: New BIC control computation is scheduled.
# Time 6.00 [sec]: Control: [1.152591674101208, 0.4664623120954221] is applied to the system.
# Time 6.02 [sec]: New BIC control is available to the controller.
# Time 6.02 [sec]: Control: [1.3256730241020878, 0.4237231105039609] is applied to the system.
# Time 6.04 [sec]: Control: [1.3256730241020878, 0.4237231105039609] is applied to the system.
# Time 6.06 [sec]: Control: [1.3256730241020878, 0.4237231105039609] is applied to the system.
# Time 6.08 [sec]: Control: [1.3256730241020878, 0.4237231105039609] is applied to the system.
# Time 6.10 [sec]: New BIC control computation is scheduled.
# Time 6.10 [sec]: Control: [1.3256730241020878, 0.4237231105039609] is applied to the system.
# Time 6.12 [sec]: New BIC control is available to the controller.
# Time 6.12 [sec]: Control: [1.0115406110495593, 0.3822925711074498] is applied to the system.
# Time 6.14 [sec]: Control: [1.0115406110495593, 0.3822925711074498] is applied to the system.
# Time 6.16 [sec]: Control: [1.0115406110495593, 0.3822925711074498] is applied to the system.
# Time 6.18 [sec]: Control: [1.0115406110495593, 0.3822925711074498] is applied to the system.
# Time 6.20 [sec]: New BIC control computation is scheduled.
# Time 6.20 [sec]: Control: [1.0115406110495593, 0.3822925711074498] is applied to the system.
# Time 6.22 [sec]: New BIC control is available to the controller.
# Time 6.22 [sec]: Control: [0.7158753766459244, 0.34245878290453635] is applied to the system.
# Time 6.24 [sec]: Control: [0.7158753766459244, 0.34245878290453635] is applied to the system.
# Time 6.26 [sec]: Control: [0.7158753766459244, 0.34245878290453635] is applied to the system.
# Time 6.28 [sec]: Control: [0.7158753766459244, 0.34245878290453635] is applied to the system.
# Time 6.30 [sec]: New BIC control computation is scheduled.
# Time 6.30 [sec]: Control: [0.7158753766459244, 0.34245878290453635] is applied to the system.
# Time 6.32 [sec]: New BIC control is available to the controller.
# Time 6.32 [sec]: Control: [0.4542091293734977, 0.30444874247600257] is applied to the system.
# Time 6.34 [sec]: Control: [0.4542091293734977, 0.30444874247600257] is applied to the system.
# Time 6.36 [sec]: Control: [0.4542091293734977, 0.30444874247600257] is applied to the system.
# Time 6.38 [sec]: Control: [0.4542091293734977, 0.30444874247600257] is applied to the system.
# Time 6.40 [sec]: New measurement is obtained.
# Time 6.40 [sec]: New BIC control computation is scheduled.
# Time 6.40 [sec]: Control: [0.4542091293734977, 0.30444874247600257] is applied to the system.
# Time 6.42 [sec]: New BIC control is available to the controller.
# Time 6.42 [sec]: Control: [0.6919254603130939, 0.2684356160567835] is applied to the system.
# Time 6.44 [sec]: Control: [0.6919254603130939, 0.2684356160567835] is applied to the system.
# Time 6.46 [sec]: Control: [0.6919254603130939, 0.2684356160567835] is applied to the system.
# Time 6.48 [sec]: Control: [0.6919254603130939, 0.2684356160567835] is applied to the system.
# Time 6.50 [sec]: New BIC control computation is scheduled.
# Time 6.50 [sec]: Control: [0.6919254603130939, 0.2684356160567835] is applied to the system.
# Time 6.52 [sec]: New BIC control is available to the controller.
# Time 6.52 [sec]: Control: [0.4365400322580603, 0.23454458976896606] is applied to the system.
# Time 6.54 [sec]: Control: [0.4365400322580603, 0.23454458976896606] is applied to the system.
# Time 6.56 [sec]: Control: [0.4365400322580603, 0.23454458976896606] is applied to the system.
# Time 6.58 [sec]: Control: [0.4365400322580603, 0.23454458976896606] is applied to the system.
# Time 6.60 [sec]: New BIC control computation is scheduled.
# Time 6.60 [sec]: Control: [0.4365400322580603, 0.23454458976896606] is applied to the system.
# Time 6.62 [sec]: New BIC control is available to the controller.
# Time 6.62 [sec]: Control: [0.19760478748558852, 0.20285834103568784] is applied to the system.
# Time 6.64 [sec]: Control: [0.19760478748558852, 0.20285834103568784] is applied to the system.
# Time 6.66 [sec]: Control: [0.19760478748558852, 0.20285834103568784] is applied to the system.
# Time 6.68 [sec]: Control: [0.19760478748558852, 0.20285834103568784] is applied to the system.
# Time 6.70 [sec]: New BIC control computation is scheduled.
# Time 6.70 [sec]: Control: [0.19760478748558852, 0.20285834103568784] is applied to the system.
# Time 6.72 [sec]: New BIC control is available to the controller.
# Time 6.72 [sec]: Control: [-0.00958213441811289, 0.1734222677500343] is applied to the system.
# Time 6.74 [sec]: Control: [-0.00958213441811289, 0.1734222677500343] is applied to the system.
# Time 6.76 [sec]: Control: [-0.00958213441811289, 0.1734222677500343] is applied to the system.
# Time 6.78 [sec]: Control: [-0.00958213441811289, 0.1734222677500343] is applied to the system.
# Time 6.80 [sec]: New measurement is obtained.
# Time 6.80 [sec]: New BIC control computation is scheduled.
# Time 6.80 [sec]: Control: [-0.00958213441811289, 0.1734222677500343] is applied to the system.
# Time 6.82 [sec]: New BIC control is available to the controller.
# Time 6.82 [sec]: Control: [0.2781475517878654, 0.14624932874346894] is applied to the system.
# Time 6.84 [sec]: Control: [0.2781475517878654, 0.14624932874346894] is applied to the system.
# Time 6.86 [sec]: Control: [0.2781475517878654, 0.14624932874346894] is applied to the system.
# Time 6.88 [sec]: Control: [0.2781475517878654, 0.14624932874346894] is applied to the system.
# Time 6.90 [sec]: New BIC control computation is scheduled.
# Time 6.90 [sec]: Control: [0.2781475517878654, 0.14624932874346894] is applied to the system.
# Time 6.92 [sec]: New BIC control is available to the controller.
# Time 6.92 [sec]: Control: [0.07215260959148556, 0.12132460137698844] is applied to the system.
# Time 6.94 [sec]: Control: [0.07215260959148556, 0.12132460137698844] is applied to the system.
# Time 6.96 [sec]: Control: [0.07215260959148556, 0.12132460137698844] is applied to the system.
# Time 6.98 [sec]: Control: [0.07215260959148556, 0.12132460137698844] is applied to the system.
# Time 7.00 [sec]: New BIC control computation is scheduled.
# Time 7.00 [sec]: Control: [0.07215260959148556, 0.12132460137698844] is applied to the system.
# Time 7.02 [sec]: New BIC control is available to the controller.
# Time 7.02 [sec]: Control: [-0.12028217220908635, 0.09860947597893886] is applied to the system.
# Time 7.04 [sec]: Control: [-0.12028217220908635, 0.09860947597893886] is applied to the system.
# Time 7.06 [sec]: Control: [-0.12028217220908635, 0.09860947597893886] is applied to the system.
# Time 7.08 [sec]: Control: [-0.12028217220908635, 0.09860947597893886] is applied to the system.
# Time 7.10 [sec]: New BIC control computation is scheduled.
# Time 7.10 [sec]: Control: [-0.12028217220908635, 0.09860947597893886] is applied to the system.
# Time 7.12 [sec]: New BIC control is available to the controller.
# Time 7.12 [sec]: Control: [-0.28403662763460935, 0.07804553026071152] is applied to the system.
# Time 7.14 [sec]: Control: [-0.28403662763460935, 0.07804553026071152] is applied to the system.
# Time 7.16 [sec]: Control: [-0.28403662763460935, 0.07804553026071152] is applied to the system.
# Time 7.18 [sec]: Control: [-0.28403662763460935, 0.07804553026071152] is applied to the system.
# Time 7.20 [sec]: New measurement is obtained.
# Time 7.20 [sec]: New BIC control computation is scheduled.
# Time 7.20 [sec]: Control: [-0.28403662763460935, 0.07804553026071152] is applied to the system.
# Time 7.22 [sec]: New BIC control is available to the controller.
# Time 7.22 [sec]: Control: [0.03286389985228579, 0.059558074190811126] is applied to the system.
# Time 7.24 [sec]: Control: [0.03286389985228579, 0.059558074190811126] is applied to the system.
# Time 7.26 [sec]: Control: [0.03286389985228579, 0.059558074190811126] is applied to the system.
# Time 7.28 [sec]: Control: [0.03286389985228579, 0.059558074190811126] is applied to the system.
# Time 7.30 [sec]: New BIC control computation is scheduled.
# Time 7.30 [sec]: Control: [0.03286389985228579, 0.059558074190811126] is applied to the system.
# Time 7.32 [sec]: New BIC control is available to the controller.
# Time 7.32 [sec]: Control: [-0.13460500601202446, 0.04305933091038871] is applied to the system.
# Time 7.34 [sec]: Control: [-0.13460500601202446, 0.04305933091038871] is applied to the system.
# Time 7.36 [sec]: Control: [-0.13460500601202446, 0.04305933091038871] is applied to the system.
# Time 7.38 [sec]: Control: [-0.13460500601202446, 0.04305933091038871] is applied to the system.
# Time 7.40 [sec]: New BIC control computation is scheduled.
# Time 7.40 [sec]: Control: [-0.13460500601202446, 0.04305933091038871] is applied to the system.
# Time 7.42 [sec]: New BIC control is available to the controller.
# Time 7.42 [sec]: Control: [-0.29133929516965007, 0.02845137382594282] is applied to the system.
# Time 7.44 [sec]: Control: [-0.29133929516965007, 0.02845137382594282] is applied to the system.
# Time 7.46 [sec]: Control: [-0.29133929516965007, 0.02845137382594282] is applied to the system.
# Time 7.48 [sec]: Control: [-0.29133929516965007, 0.02845137382594282] is applied to the system.
# Time 7.50 [sec]: New BIC control computation is scheduled.
# Time 7.50 [sec]: Control: [-0.29133929516965007, 0.02845137382594282] is applied to the system.
# Time 7.52 [sec]: New BIC control is available to the controller.
# Time 7.52 [sec]: Control: [-0.42257674783526705, 0.015628699280173682] is applied to the system.
# Time 7.54 [sec]: Control: [-0.42257674783526705, 0.015628699280173682] is applied to the system.
# Time 7.56 [sec]: Control: [-0.42257674783526705, 0.015628699280173682] is applied to the system.
# Time 7.58 [sec]: Control: [-0.42257674783526705, 0.015628699280173682] is applied to the system.
# Time 7.60 [sec]: New measurement is obtained.
# Time 7.60 [sec]: New BIC control computation is scheduled.
# Time 7.60 [sec]: Control: [-0.42257674783526705, 0.015628699280173682] is applied to the system.
# Time 7.62 [sec]: New BIC control is available to the controller.
# Time 7.62 [sec]: Control: [-0.10114517151978802, 0.0044805357342814255] is applied to the system.
# Time 7.64 [sec]: Control: [-0.10114517151978802, 0.0044805357342814255] is applied to the system.
# Time 7.66 [sec]: Control: [-0.10114517151978802, 0.0044805357342814255] is applied to the system.
# Time 7.68 [sec]: Control: [-0.10114517151978802, 0.0044805357342814255] is applied to the system.
# Time 7.70 [sec]: New BIC control computation is scheduled.
# Time 7.70 [sec]: Control: [-0.10114517151978802, 0.0044805357342814255] is applied to the system.
# Time 7.72 [sec]: New BIC control is available to the controller.
# Time 7.72 [sec]: Control: [-0.23917432042993916, -0.005107106944107439] is applied to the system.
# Time 7.74 [sec]: Control: [-0.23917432042993916, -0.005107106944107439] is applied to the system.
# Time 7.76 [sec]: Control: [-0.23917432042993916, -0.005107106944107439] is applied to the system.
# Time 7.78 [sec]: Control: [-0.23917432042993916, -0.005107106944107439] is applied to the system.
# Time 7.80 [sec]: New BIC control computation is scheduled.
# Time 7.80 [sec]: Control: [-0.23917432042993916, -0.005107106944107439] is applied to the system.
# Time 7.82 [sec]: New BIC control is available to the controller.
# Time 7.82 [sec]: Control: [-0.36869994510913895, -0.013249684083306354] is applied to the system.
# Time 7.84 [sec]: Control: [-0.36869994510913895, -0.013249684083306354] is applied to the system.
# Time 7.86 [sec]: Control: [-0.36869994510913895, -0.013249684083306354] is applied to the system.
# Time 7.88 [sec]: Control: [-0.36869994510913895, -0.013249684083306354] is applied to the system.
# Time 7.90 [sec]: New BIC control computation is scheduled.
# Time 7.90 [sec]: Control: [-0.36869994510913895, -0.013249684083306354] is applied to the system.
# Time 7.92 [sec]: New BIC control is available to the controller.
# Time 7.92 [sec]: Control: [-0.475745649020672, -0.02006255761107713] is applied to the system.
# Time 7.94 [sec]: Control: [-0.475745649020672, -0.02006255761107713] is applied to the system.
# Time 7.96 [sec]: Control: [-0.475745649020672, -0.02006255761107713] is applied to the system.
# Time 7.98 [sec]: Control: [-0.475745649020672, -0.02006255761107713] is applied to the system.
# Time 8.00 [sec]: New measurement is obtained.
# Time 8.00 [sec]: New BIC control computation is scheduled.
# Time 8.00 [sec]: Control: [-0.475745649020672, -0.02006255761107713] is applied to the system.
# Time 8.02 [sec]: New BIC control is available to the controller.
# Time 8.02 [sec]: Control: [-0.17655346768123562, -0.025659697998616456] is applied to the system.
# Time 8.04 [sec]: Control: [-0.17655346768123562, -0.025659697998616456] is applied to the system.
# Time 8.06 [sec]: Control: [-0.17655346768123562, -0.025659697998616456] is applied to the system.
# Time 8.08 [sec]: Control: [-0.17655346768123562, -0.025659697998616456] is applied to the system.
# Time 8.10 [sec]: New BIC control computation is scheduled.
# Time 8.10 [sec]: Control: [-0.17655346768123562, -0.025659697998616456] is applied to the system.
# Time 8.12 [sec]: New BIC control is available to the controller.
# Time 8.12 [sec]: Control: [-0.29068783910867235, -0.03015257296042629] is applied to the system.
# Time 8.14 [sec]: Control: [-0.29068783910867235, -0.03015257296042629] is applied to the system.
# Time 8.16 [sec]: Control: [-0.29068783910867235, -0.03015257296042629] is applied to the system.
# Time 8.18 [sec]: Control: [-0.29068783910867235, -0.03015257296042629] is applied to the system.
# Time 8.20 [sec]: New BIC control computation is scheduled.
# Time 8.20 [sec]: Control: [-0.29068783910867235, -0.03015257296042629] is applied to the system.
# Time 8.22 [sec]: New BIC control is available to the controller.
# Time 8.22 [sec]: Control: [-0.39773946788626885, -0.03364920516641749] is applied to the system.
# Time 8.24 [sec]: Control: [-0.39773946788626885, -0.03364920516641749] is applied to the system.
# Time 8.26 [sec]: Control: [-0.39773946788626885, -0.03364920516641749] is applied to the system.
# Time 8.28 [sec]: Control: [-0.39773946788626885, -0.03364920516641749] is applied to the system.
# Time 8.30 [sec]: New BIC control computation is scheduled.
# Time 8.30 [sec]: Control: [-0.39773946788626885, -0.03364920516641749] is applied to the system.
# Time 8.32 [sec]: New BIC control is available to the controller.
# Time 8.32 [sec]: Control: [-0.48517765335900737, -0.03625346653753477] is applied to the system.
# Time 8.34 [sec]: Control: [-0.48517765335900737, -0.03625346653753477] is applied to the system.
# Time 8.36 [sec]: Control: [-0.48517765335900737, -0.03625346653753477] is applied to the system.
# Time 8.38 [sec]: Control: [-0.48517765335900737, -0.03625346653753477] is applied to the system.
# Time 8.40 [sec]: New measurement is obtained.
# Time 8.40 [sec]: New BIC control computation is scheduled.
# Time 8.40 [sec]: Control: [-0.48517765335900737, -0.03625346653753477] is applied to the system.
# Time 8.42 [sec]: New BIC control is available to the controller.
# Time 8.42 [sec]: Control: [-0.2349766569310128, -0.03806445952457282] is applied to the system.
# Time 8.44 [sec]: Control: [-0.2349766569310128, -0.03806445952457282] is applied to the system.
# Time 8.46 [sec]: Control: [-0.2349766569310128, -0.03806445952457282] is applied to the system.
# Time 8.48 [sec]: Control: [-0.2349766569310128, -0.03806445952457282] is applied to the system.
# Time 8.50 [sec]: New BIC control computation is scheduled.
# Time 8.50 [sec]: Control: [-0.2349766569310128, -0.03806445952457282] is applied to the system.
# Time 8.52 [sec]: New BIC control is available to the controller.
# Time 8.52 [sec]: Control: [-0.3267323294964732, -0.0391760748382941] is applied to the system.
# Time 8.54 [sec]: Control: [-0.3267323294964732, -0.0391760748382941] is applied to the system.
# Time 8.56 [sec]: Control: [-0.3267323294964732, -0.0391760748382941] is applied to the system.
# Time 8.58 [sec]: Control: [-0.3267323294964732, -0.0391760748382941] is applied to the system.
# Time 8.60 [sec]: New BIC control computation is scheduled.
# Time 8.60 [sec]: Control: [-0.3267323294964732, -0.0391760748382941] is applied to the system.
# Time 8.62 [sec]: New BIC control is available to the controller.
# Time 8.62 [sec]: Control: [-0.4120450462725245, -0.039676667726687834] is applied to the system.
# Time 8.64 [sec]: Control: [-0.4120450462725245, -0.039676667726687834] is applied to the system.
# Time 8.66 [sec]: Control: [-0.4120450462725245, -0.039676667726687834] is applied to the system.
# Time 8.68 [sec]: Control: [-0.4120450462725245, -0.039676667726687834] is applied to the system.
# Time 8.70 [sec]: New BIC control computation is scheduled.
# Time 8.70 [sec]: Control: [-0.4120450462725245, -0.039676667726687834] is applied to the system.
# Time 8.72 [sec]: New BIC control is available to the controller.
# Time 8.72 [sec]: Control: [-0.48064847948063594, -0.03964883257702199] is applied to the system.
# Time 8.74 [sec]: Control: [-0.48064847948063594, -0.03964883257702199] is applied to the system.
# Time 8.76 [sec]: Control: [-0.48064847948063594, -0.03964883257702199] is applied to the system.
# Time 8.78 [sec]: Control: [-0.48064847948063594, -0.03964883257702199] is applied to the system.
# Time 8.80 [sec]: New measurement is obtained.
# Time 8.80 [sec]: New BIC control computation is scheduled.
# Time 8.80 [sec]: Control: [-0.48064847948063594, -0.03964883257702199] is applied to the system.
# Time 8.82 [sec]: New BIC control is available to the controller.
# Time 8.82 [sec]: Control: [-0.3021351595551367, -0.03916930360492403] is applied to the system.
# Time 8.84 [sec]: Control: [-0.3021351595551367, -0.03916930360492403] is applied to the system.
# Time 8.86 [sec]: Control: [-0.3021351595551367, -0.03916930360492403] is applied to the system.
# Time 8.88 [sec]: Control: [-0.3021351595551367, -0.03916930360492403] is applied to the system.
# Time 8.90 [sec]: New BIC control computation is scheduled.
# Time 8.90 [sec]: Control: [-0.3021351595551367, -0.03916930360492403] is applied to the system.
# Time 8.92 [sec]: New BIC control is available to the controller.
# Time 8.92 [sec]: Control: [-0.3697007436354062, -0.03830891301007073] is applied to the system.
# Time 8.94 [sec]: Control: [-0.3697007436354062, -0.03830891301007073] is applied to the system.
# Time 8.96 [sec]: Control: [-0.3697007436354062, -0.03830891301007073] is applied to the system.
# Time 8.98 [sec]: Control: [-0.3697007436354062, -0.03830891301007073] is applied to the system.
# Time 9.00 [sec]: New BIC control computation is scheduled.
# Time 9.00 [sec]: Control: [-0.3697007436354062, -0.03830891301007073] is applied to the system.
# Time 9.02 [sec]: New BIC control is available to the controller.
# Time 9.02 [sec]: Control: [-0.4309209293869859, -0.037132597408557094] is applied to the system.
# Time 9.04 [sec]: Control: [-0.4309209293869859, -0.037132597408557094] is applied to the system.
# Time 9.06 [sec]: Control: [-0.4309209293869859, -0.037132597408557094] is applied to the system.
# Time 9.08 [sec]: Control: [-0.4309209293869859, -0.037132597408557094] is applied to the system.
# Time 9.10 [sec]: New BIC control computation is scheduled.
# Time 9.10 [sec]: Control: [-0.4309209293869859, -0.037132597408557094] is applied to the system.
# Time 9.12 [sec]: New BIC control is available to the controller.
# Time 9.12 [sec]: Control: [-0.4785989551576918, -0.03569959579640289] is applied to the system.
# Time 9.14 [sec]: Control: [-0.4785989551576918, -0.03569959579640289] is applied to the system.
# Time 9.16 [sec]: Control: [-0.4785989551576918, -0.03569959579640289] is applied to the system.
# Time 9.18 [sec]: Control: [-0.4785989551576918, -0.03569959579640289] is applied to the system.
# Time 9.20 [sec]: New measurement is obtained.
# Time 9.20 [sec]: New BIC control computation is scheduled.
# Time 9.20 [sec]: Control: [-0.4785989551576918, -0.03569959579640289] is applied to the system.
# Time 9.22 [sec]: New BIC control is available to the controller.
# Time 9.22 [sec]: Control: [-0.38305740690483236, -0.034063468431917765] is applied to the system.
# Time 9.24 [sec]: Control: [-0.38305740690483236, -0.034063468431917765] is applied to the system.
# Time 9.26 [sec]: Control: [-0.38305740690483236, -0.034063468431917765] is applied to the system.
# Time 9.28 [sec]: Control: [-0.38305740690483236, -0.034063468431917765] is applied to the system.
# Time 9.30 [sec]: New BIC control computation is scheduled.
# Time 9.30 [sec]: Control: [-0.38305740690483236, -0.034063468431917765] is applied to the system.
# Time 9.32 [sec]: New BIC control is available to the controller.
# Time 9.32 [sec]: Control: [-0.42327464227317557, -0.03227239314029968] is applied to the system.
# Time 9.34 [sec]: Control: [-0.42327464227317557, -0.03227239314029968] is applied to the system.
# Time 9.36 [sec]: Control: [-0.42327464227317557, -0.03227239314029968] is applied to the system.
# Time 9.38 [sec]: Control: [-0.42327464227317557, -0.03227239314029968] is applied to the system.
# Time 9.40 [sec]: New BIC control computation is scheduled.
# Time 9.40 [sec]: Control: [-0.42327464227317557, -0.03227239314029968] is applied to the system.
# Time 9.42 [sec]: New BIC control is available to the controller.
# Time 9.42 [sec]: Control: [-0.4571448841661337, -0.030369391955893346] is applied to the system.
# Time 9.44 [sec]: Control: [-0.4571448841661337, -0.030369391955893346] is applied to the system.
# Time 9.46 [sec]: Control: [-0.4571448841661337, -0.030369391955893346] is applied to the system.
# Time 9.48 [sec]: Control: [-0.4571448841661337, -0.030369391955893346] is applied to the system.
# Time 9.50 [sec]: New BIC control computation is scheduled.
# Time 9.50 [sec]: Control: [-0.4571448841661337, -0.030369391955893346] is applied to the system.
# Time 9.52 [sec]: New BIC control is available to the controller.
# Time 9.52 [sec]: Control: [-0.48101176184626865, -0.028392484991042414] is applied to the system.
# Time 9.54 [sec]: Control: [-0.48101176184626865, -0.028392484991042414] is applied to the system.
# Time 9.56 [sec]: Control: [-0.48101176184626865, -0.028392484991042414] is applied to the system.
# Time 9.58 [sec]: Control: [-0.48101176184626865, -0.028392484991042414] is applied to the system.
# Time 9.60 [sec]: New measurement is obtained.
# Time 9.60 [sec]: New BIC control computation is scheduled.
# Time 9.60 [sec]: Control: [-0.48101176184626865, -0.028392484991042414] is applied to the system.
# Time 9.62 [sec]: New BIC control is available to the controller.
# Time 9.62 [sec]: Control: [-0.45645249351580747, -0.02637510307773645] is applied to the system.
# Time 9.64 [sec]: Control: [-0.45645249351580747, -0.02637510307773645] is applied to the system.
# Time 9.66 [sec]: Control: [-0.45645249351580747, -0.02637510307773645] is applied to the system.
# Time 9.68 [sec]: Control: [-0.45645249351580747, -0.02637510307773645] is applied to the system.
# Time 9.70 [sec]: New BIC control computation is scheduled.
# Time 9.70 [sec]: Control: [-0.45645249351580747, -0.02637510307773645] is applied to the system.
# Time 9.72 [sec]: New BIC control is available to the controller.
# Time 9.72 [sec]: Control: [-0.468296517127491, -0.024346272160097705] is applied to the system.
# Time 9.74 [sec]: Control: [-0.468296517127491, -0.024346272160097705] is applied to the system.
# Time 9.76 [sec]: Control: [-0.468296517127491, -0.024346272160097705] is applied to the system.
# Time 9.78 [sec]: Control: [-0.468296517127491, -0.024346272160097705] is applied to the system.
# Time 9.80 [sec]: New BIC control computation is scheduled.
# Time 9.80 [sec]: Control: [-0.468296517127491, -0.024346272160097705] is applied to the system.
# Time 9.82 [sec]: New BIC control is available to the controller.
# Time 9.82 [sec]: Control: [-0.4743520633220147, -0.022330983223569946] is applied to the system.
# Time 9.84 [sec]: Control: [-0.4743520633220147, -0.022330983223569946] is applied to the system.
# Time 9.86 [sec]: Control: [-0.4743520633220147, -0.022330983223569946] is applied to the system.
# Time 9.88 [sec]: Control: [-0.4743520633220147, -0.022330983223569946] is applied to the system.
# Time 9.90 [sec]: New BIC control computation is scheduled.
# Time 9.90 [sec]: Control: [-0.4743520633220147, -0.022330983223569946] is applied to the system.
# Time 9.92 [sec]: New BIC control is available to the controller.
# Time 9.92 [sec]: Control: [-0.47412464493592454, -0.020350420314591996] is applied to the system.
# Time 9.94 [sec]: Control: [-0.47412464493592454, -0.020350420314591996] is applied to the system.
# Time 9.96 [sec]: Control: [-0.47412464493592454, -0.020350420314591996] is applied to the system.
# Time 9.98 [sec]: Control: [-0.47412464493592454, -0.020350420314591996] is applied to the system.
# Time 10.00 [sec]: New measurement is obtained.

# %%
result.total_cnt_cost
# Out:
# 0.9428489094765229

# %%
result.total_pos_cost
# Out:
# 0.6899813005774554

# %%
result.total_col_cost
# Out:
# 42.83063189594042

# %%
result.total_cnt_cost + result.total_pos_cost + result.total_col_cost
# Out:
# 44.4634621059944

# %%
minimum([minimum(vcat([norm(get_position(w.e_state) - ap) for ap in values(w.ap_dict)], Inf))
                          for w in result.w_history])
# Out:
# 0.5037995099704482

# %%
make_gif(result, dtplot=0.02, fps=50, xlim=(-6., 6.), ylim=(-6., 6.), figsize=(600, 400), 
         legendfontsize=7, legend=:topright, markersize=5., filename="5_bic_synthetic.gif")
# Out:
# ┌ Warning: No prediction is available with BIC Controller
# └ @ RiskSensitiveSAC /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/src/utils.jl:619
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:27
# ┌ Info: Saved animation to
# │   fn = /home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/5_bic_synthetic.gif
# └ @ Plots /home/haruki/.julia/packages/Plots/qZHsp/src/animation.jl:98
# Plots.AnimatedGif("/home/haruki/Documents/2020-21_Autumn/RiskSensitiveSAC.jl/notebook/5_bic_synthetic.gif")

# %%
save("5_bic_synthetic.jld2", "result", result)
